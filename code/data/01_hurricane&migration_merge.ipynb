# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Loading in the data

# %%
fema = pd.read_csv('../../data/DisasterDeclarationsSummaries.csv')

# %%
hurricanes = pd.read_csv('../../data/hurdat2_flat.csv')

# %%
migration_folder = '../../data/IRS Migration'

year_mappings = {
    '1617': {'year':2017, 'label':'2016-2017'},
    '1718': {'year':2018, 'label':'2017-2018'},
    '1819': {'year':2019, 'label':'2018-2019'},
    '1920': {'year':2020, 'label':'2019-2020'},
    '2021': {'year':2021, 'label':'2020-2021'},
    '2122': {'year':2022, 'label':'2021-2022'}
}

# %%
all_inflow = []
all_outflow = []

for year_code, year_info in year_mappings.items():
    inflow_file = os.path.join(migration_folder, f'countyinflow{year_code}.csv')
    outflow_file = os.path.join(migration_folder, f'countyoutflow{year_code}.csv')
    
    inflow_df = pd.read_csv(inflow_file, encoding='cp1252')
    outflow_df = pd.read_csv(outflow_file, encoding='cp1252')
    
    inflow_df['year'] = year_info['year']
    inflow_df['year_label'] = year_info['label']
    
    outflow_df['year'] = year_info['year']
    outflow_df['year_label'] = year_info['label']
    
    all_inflow.append(inflow_df)
    all_outflow.append(outflow_df)

# %%
inflow_combined = pd.concat(all_inflow, ignore_index=True)
outflow_combined = pd.concat(all_outflow, ignore_index=True)

# %%
len(inflow_combined), len(outflow_combined)

sorted(inflow_combined['year'].unique()), sorted(outflow_combined['year'].unique())
# Out:
# ([np.int64(2017),
#   np.int64(2018),
#   np.int64(2019),
#   np.int64(2020),
#   np.int64(2021),
#   np.int64(2022)],
#  [np.int64(2017),
#   np.int64(2018),
#   np.int64(2019),
#   np.int64(2020),
#   np.int64(2021),
#   np.int64(2022)])

# %%
# Filter to only Florida (state FIPS code = 12)

inflow_combined = inflow_combined[
    (inflow_combined['y2_statefips'] == 12)
].copy()

outflow_combined = outflow_combined[
    (outflow_combined['y1_statefips'] == 12)
].copy()

# %% [markdown]
# # 2. Preparing FEMA Data

# %%
# Only FL
fema = fema[fema['state'] == 'FL'].copy()
print(f"Filtered FEMA to FL: {len(fema)} rows")
# Out:
# Filtered FEMA to FL: 2791 rows

# %%
# Re-classing dates

fema['declarationDate'] = pd.to_datetime(fema['declarationDate'])
fema['incidentBeginDate'] = pd.to_datetime(fema['incidentBeginDate'])
fema['incidentEndDate'] = pd.to_datetime(fema['incidentEndDate'])

# %%
# Creating combined FIPS

fema['fips'] = (fema['fipsStateCode'].astype(str).str.zfill(2) + 
fema['fipsCountyCode'].astype(str).str.zfill(3))

# Adding year for matching

fema['year'] = fema['incidentBeginDate'].dt.year

# %%
# Quick validation

print(f"Data range: {fema['incidentBeginDate'].min()} - {fema['incidentBeginDate'].max()}")
# Out:
# Data range: 1953-10-22 00:00:00+00:00 - 2024-10-05 00:00:00+00:00

# %%
# Isolating hurricane-related declarations

hurricane_keywords = ['hurricane', 'tropical storm', 'tropical', 'cyclone', 'severe storm']
hurricane_mask = (fema['incidentType'].str.lower().str.contains('|'.join(hurricane_keywords), na=False) | 
fema['declarationTitle'].str.lower().str.contains('|'.join(hurricane_keywords), na=False))

fema_hurricanes = fema[hurricane_mask].copy()

# %%
# Filtering to 2017-2022 only

fema_hurricanes = fema_hurricanes[
    (fema_hurricanes['year'] >= 2017) & 
    (fema_hurricanes['year'] <= 2022)
].copy()

# %%
# Quick validation

print(f"There are {len(fema_hurricanes)} hurricane-related disaster declarations, spanning {fema_hurricanes['year'].min()} to {fema_hurricanes['year'].max()}.")
print(f"Years that have hurricane declarations: {sorted(fema_hurricanes['year'].unique())}")
# Out:
# There are 663 hurricane-related disaster declarations, spanning 2017 to 2022.
# Years that have hurricane declarations: [np.int32(2017), np.int32(2018), np.int32(2019), np.int32(2020), np.int32(2021), np.int32(2022)]

# %% [markdown]
# # 3. Preparing IRS Migration Data

# %%
# FIPS Codes for inflow

inflow_combined['destination_fips'] = (inflow_combined['y2_statefips'].astype(str).str.zfill(2) + 
inflow_combined['y2_countyfips'].astype(str).str.zfill(3))

inflow_combined['origin_fips'] = (inflow_combined['y1_statefips'].astype(str).str.zfill(2) + 
inflow_combined['y1_countyfips'].astype(str).str.zfill(3))

# %%
# FIPS Codes for outflow

outflow_combined['origin_fips'] = (outflow_combined['y1_statefips'].astype(str).str.zfill(2) + 
outflow_combined['y1_countyfips'].astype(str).str.zfill(3))

outflow_combined['destination_fips'] = (outflow_combined['y2_statefips'].astype(str).str.zfill(2) + 
outflow_combined['y2_countyfips'].astype(str).str.zfill(3))

# %%
# Aggregating by county and year

outflow_summary = outflow_combined.groupby(['origin_fips', 'year']).agg({
    'n1' : 'sum', # Tax Returns (Households)
    'n2' : 'sum', # People
    'agi' : 'sum' # Income
}).reset_index()

outflow_summary.columns = ['fips', 'year', 'outflow_returns', 'outflow_people', 'outflow_agi']

inflow_summary = inflow_combined.groupby(['destination_fips', 'year']).agg({
    'n1' : 'sum', # Tax Returns (Households)
    'n2' : 'sum', # People
    'agi' : 'sum' # Income
}).reset_index()

inflow_summary.columns = ['fips', 'year', 'inflow_returns', 'inflow_people', 'inflow_agi']

# %%
# Merging

migration_summary = outflow_summary.merge(
    inflow_summary,
    on=['fips', 'year'],
    how='outer'
)

# %%
# Adding columns for net migration

migration_summary['net_migration_returns'] = (
    migration_summary['inflow_returns'] - migration_summary['outflow_returns']
)

migration_summary['net_migration_people'] = (
    migration_summary['inflow_people'] - migration_summary['outflow_people']
)

# %%
print(f"Unique county-year combinations: {len(migration_summary):,}")
# Out:
# Unique county-year combinations: 404

# %% [markdown]
# # 4. Preparing HURDAT Data

# %%
hurricanes = pd.read_csv('../../data/hurdat2_flat.csv')

# %%
hurricanes.head()
# Out:
#    Storm_ID Storm_Name        Date  Time Status Latitude Longitude  \
# 0  AL011851    UNNAMED  1851-06-25     0     HU    28.0N     94.8W
# 1  AL011851    UNNAMED  1851-06-25   600     HU    28.0N     95.4W
# 2  AL011851    UNNAMED  1851-06-25  1200     HU    28.0N     96.0W
# 3  AL011851    UNNAMED  1851-06-25  1800     HU    28.1N     96.5W
# 4  AL011851    UNNAMED  1851-06-25  2100     HU    28.2N     96.8W
#
#    Latitude_Numeric  Longitude_Numeric  Max_Wind  ...  NW_34kt NE_50kt  \
# 0              28.0              -94.8        80  ...      NaN     NaN
# 1              28.0              -95.4        80  ...      NaN     NaN
# 2              28.0              -96.0        80  ...      NaN     NaN
# 3              28.1              -96.5        80  ...      NaN     NaN
# 4              28.2              -96.8        80  ...      NaN     NaN
#
#    SE_50kt  SW_50kt  NW_50kt  NE_64kt  SE_64kt  SW_64kt  NW_64kt  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Max_Wind_Radius
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 25 columns]

# %%
hurricanes['Date'] = pd.to_datetime(hurricanes['Date'], format='%Y-%m-%d', errors='coerce')
hurricanes['Year'] = hurricanes['Date'].dt.year

# %%
# Filtering so it matches IRS

available_years = sorted(migration_summary['year'].unique())
hurricanes_filtered = hurricanes[hurricanes['Year'].isin(available_years)].copy()

storm_summary = hurricanes_filtered.groupby(['Storm_ID']).agg({
    'Storm_Name': 'first',
    'Date': ['min', 'max'],
    'Max_Wind': 'max',
    'Min_Pressure': 'min',
    'Year': 'first'
}).reset_index()

storm_summary.columns = ['Storm_ID', 'Storm_Name', 'Start_Date', 'End_Date', 
                         'Max_Wind_Speed', 'Min_Pressure', 'Year']

# %%
print(f"  Years: {available_years}")
# Out:
#   Years: [np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022)]

# %%
storm_summary.head()
# Out:
#    Storm_ID Storm_Name Start_Date   End_Date  Max_Wind_Speed  Min_Pressure  \
# 0  AL012017     ARLENE 2017-04-16 2017-04-22              55         986.0
# 1  AL012018    ALBERTO 2018-05-25 2018-05-31              55         990.0
# 2  AL012019     ANDREA 2019-05-20 2019-05-22              35        1006.0
# 3  AL012020     ARTHUR 2020-05-16 2020-05-21              55         989.0
# 4  AL012021        ANA 2021-05-20 2021-05-24              50        1004.0
#
#    Year
# 0  2017
# 1  2018
# 2  2019
# 3  2020
# 4  2021

# %%
print(f"In the available years for migration data, there are {len(storm_summary)} unique storms.")
print(f"The storms start as early as {storm_summary['Start_Date'].min().date()} and go until {storm_summary['End_Date'].max().date()}.")
# Out:
# In the available years for migration data, there are 122 unique storms.
# The storms start as early as 2017-04-16 and go until 2022-11-11.

# %% [markdown]
# # 5. Merging

# %%
# Merging Declarations with IRS Migration

fema_migration = fema_hurricanes.merge(
    migration_summary,
    on=['fips', 'year'],
    how='left'
)

# %%
fema_migration.head()
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            DR-4680-FL            4680    FL              DR
# 1            DR-4680-FL            4680    FL              DR
# 2            DR-4680-FL            4680    FL              DR
# 3            DR-4680-FL            4680    FL              DR
# 4            DR-4680-FL            4680    FL              DR
#
#             declarationDate  fyDeclared incidentType  declarationTitle  \
# 0 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 1 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 2 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 3 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 4 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
#
#    ihProgramDeclared  iaProgramDeclared  ...   fips  year outflow_returns  \
# 0                  0                  0  ...  12001  2022        133864.0
# 1                  0                  0  ...  12003  2022         12078.0
# 2                  0                  0  ...  12007  2022         10888.0
# 3                  0                  0  ...  12011  2022        999987.0
# 4                  0                  0  ...  12013  2022          4986.0
#
#   outflow_people outflow_agi  inflow_returns  inflow_people  inflow_agi  \
# 0       236905.0  10594863.0        131143.0       235518.0  10528909.0
# 1        25438.0    747938.0         12620.0        26869.0    806790.0
# 2        21990.0    601863.0         12262.0        24667.0    666370.0
# 3      1808085.0  93860199.0        994604.0      1786372.0  99337673.0
# 4        10408.0    261886.0          5402.0        11180.0    286455.0
#
#    net_migration_returns net_migration_people
# 0                -2721.0              -1387.0
# 1                  542.0               1431.0
# 2                 1374.0               2677.0
# 3                -5383.0             -21713.0
# 4                  416.0                772.0
#
# [5 rows x 38 columns]

# %%
# Adding HURDAT2 Storm Info

fema_migration_storms = fema_migration.copy()

if len(storm_summary) > 0:
    for idx, row in storm_summary.iterrows():
        storm_name = row['Storm_Name']
        if pd.notna(storm_name):
            mask = (
                fema_migration_storms['declarationTitle'].str.contains(storm_name, case=False, na=False) &
                (fema_migration_storms['year'] == row['Year'])
            )
            fema_migration_storms.loc[mask, 'matched_storm_id'] = row['Storm_ID']
            fema_migration_storms.loc[mask, 'max_wind_speed'] = row['Max_Wind_Speed']
            fema_migration_storms.loc[mask, 'min_pressure'] = row['Min_Pressure']

    matched = fema_migration_storms['matched_storm_id'].notna().sum()
    print(f"Matched {matched} records to storm tracks.")
# Out:
# Matched 663 records to storm tracks.

# %%
fema_migration_storms.head()
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            DR-4680-FL            4680    FL              DR
# 1            DR-4680-FL            4680    FL              DR
# 2            DR-4680-FL            4680    FL              DR
# 3            DR-4680-FL            4680    FL              DR
# 4            DR-4680-FL            4680    FL              DR
#
#             declarationDate  fyDeclared incidentType  declarationTitle  \
# 0 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 1 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 2 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 3 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 4 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
#
#    ihProgramDeclared  iaProgramDeclared  ...  outflow_people  outflow_agi  \
# 0                  0                  0  ...        236905.0   10594863.0
# 1                  0                  0  ...         25438.0     747938.0
# 2                  0                  0  ...         21990.0     601863.0
# 3                  0                  0  ...       1808085.0   93860199.0
# 4                  0                  0  ...         10408.0     261886.0
#
#   inflow_returns inflow_people  inflow_agi  net_migration_returns  \
# 0       131143.0      235518.0  10528909.0                -2721.0
# 1        12620.0       26869.0    806790.0                  542.0
# 2        12262.0       24667.0    666370.0                 1374.0
# 3       994604.0     1786372.0  99337673.0                -5383.0
# 4         5402.0       11180.0    286455.0                  416.0
#
#    net_migration_people  matched_storm_id  max_wind_speed min_pressure
# 0               -1387.0          AL172022            65.0        980.0
# 1                1431.0          AL172022            65.0        980.0
# 2                2677.0          AL172022            65.0        980.0
# 3              -21713.0          AL172022            65.0        980.0
# 4                 772.0          AL172022            65.0        980.0
#
# [5 rows x 41 columns]

# %% [markdown]
# # 6. Creating Summaries

# %% [markdown]
# ## 6.1. Hurricane impact by county

# %%
# Hurricane impact by county

hurricane_county_summary = fema_migration_storms.groupby('fips').agg({
    'disasterNumber': 'count',
    'state': 'first',
    'designatedArea': 'first',
    'year': lambda x: ', '.join(map(str, sorted(x.unique()))),
    'outflow_returns': 'sum',
    'inflow_returns': 'sum',
    'net_migration_returns': 'sum',
    'outflow_people': 'sum',
    'inflow_people': 'sum',
    'net_migration_people': 'sum',
    'outflow_agi': 'sum', # Income leaving the county
    'inflow_agi': 'sum', # Income entering the county
    'max_wind_speed': 'max'
}).reset_index()

# Renaming for aesthetic reasons

hurricane_county_summary.columns = [
        'fips', 'num_hurricane_declarations', 'state', 'county_name', 'years_affected',
        'outflow_returns', 'inflow_returns', 'net_migration_returns',
        'outflow_people', 'inflow_people', 'net_migration_people',
        'outflow_agi', 'inflow_agi', 'max_wind_speed'
    ]

# %%
hurricane_county_summary.head()
# Out:
#     fips  num_hurricane_declarations state                     county_name  \
# 0  12000                          34    FL  Big Cypress Indian Reservation
# 1  12001                          10    FL                Alachua (County)
# 2  12003                           8    FL                  Baker (County)
# 3  12005                          10    FL                    Bay (County)
# 4  12007                           9    FL               Bradford (County)
#
#                        years_affected  outflow_returns  inflow_returns  \
# 0                    2017, 2019, 2022       14521283.0      16434607.0
# 1  2017, 2018, 2019, 2020, 2021, 2022        1298659.0       1258165.0
# 2        2017, 2018, 2019, 2021, 2022          89801.0         94208.0
# 3  2017, 2018, 2019, 2020, 2021, 2022         924011.0        931916.0
# 4        2017, 2018, 2019, 2021, 2022          96450.0        105055.0
#
#    net_migration_returns  outflow_people  inflow_people  net_migration_people  \
# 0              1913324.0      26537287.0     30565927.0             4028640.0
# 1               -40494.0       2359026.0      2320187.0              -38839.0
# 2                 4407.0        194985.0       206382.0               11397.0
# 3                 7905.0       1818525.0      1833234.0               14709.0
# 4                 8605.0        198636.0       215506.0               16870.0
#
#    outflow_agi    inflow_agi  max_wind_speed
# 0  798212478.0  1.124438e+09           160.0
# 1   93275814.0  9.178640e+07           160.0
# 2    5207214.0  5.589318e+06           160.0
# 3   57269254.0  6.022466e+07           160.0
# 4    4968764.0  5.359301e+06           160.0

# %%
# Creating a new column indicating rate of migration

hurricane_county_summary['outflow_rate'] = (
    hurricane_county_summary['outflow_returns'] / 
    (hurricane_county_summary['outflow_returns'] + hurricane_county_summary['inflow_returns'] * 100)
)

hurricane_county_summary['outflow_rate'].head()
# Out:
# 0    0.008758
# 1    0.010216
# 2    0.009442
# 3    0.009818
# 4    0.009097
# Name: outflow_rate, dtype: float64

# %% [markdown]
# ## 6.2. County-year level

# %%
with pd.option_context('display.max_columns', None):
    display(fema_migration_storms.head())
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            DR-4680-FL            4680    FL              DR
# 1            DR-4680-FL            4680    FL              DR
# 2            DR-4680-FL            4680    FL              DR
# 3            DR-4680-FL            4680    FL              DR
# 4            DR-4680-FL            4680    FL              DR
#
#             declarationDate  fyDeclared incidentType  declarationTitle  \
# 0 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 1 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 2 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 3 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 4 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
#
#    ihProgramDeclared  iaProgramDeclared  paProgramDeclared  hmProgramDeclared  \
# 0                  0                  0                  1                  1
# 1                  0                  0                  1                  1
# 2                  0                  0                  1                  1
# 3                  0                  0                  1                  1
# 4                  0                  0                  1                  1
#
#           incidentBeginDate           incidentEndDate disasterCloseoutDate  \
# 0 2022-11-07 00:00:00+00:00 2022-11-30 00:00:00+00:00                  NaN
# 1 2022-11-07 00:00:00+00:00 2022-11-30 00:00:00+00:00                  NaN
# 2 2022-11-07 00:00:00+00:00 2022-11-30 00:00:00+00:00                  NaN
# 3 2022-11-07 00:00:00+00:00 2022-11-30 00:00:00+00:00                  NaN
# 4 2022-11-07 00:00:00+00:00 2022-11-30 00:00:00+00:00                  NaN
#
#    tribalRequest  fipsStateCode  fipsCountyCode  placeCode     designatedArea  \
# 0              0             12               1      99001   Alachua (County)
# 1              0             12               3      99003     Baker (County)
# 2              0             12               7      99007  Bradford (County)
# 3              0             12              11      99011   Broward (County)
# 4              0             12              13      99013   Calhoun (County)
#
#    declarationRequestNumber          lastIAFilingDate  incidentId  region  \
# 0                     22104  2023-02-13T00:00:00.000Z  2022110701       4
# 1                     22104  2023-02-13T00:00:00.000Z  2022110701       4
# 2                     22104  2023-02-13T00:00:00.000Z  2022110701       4
# 3                     22104  2023-02-13T00:00:00.000Z  2022110701       4
# 4                     22104  2023-02-13T00:00:00.000Z  2022110701       4
#
#   designatedIncidentTypes               lastRefresh  \
# 0                     4,H  2024-08-27T18:22:14.800Z
# 1                     4,H  2024-08-27T18:22:14.800Z
# 2                     4,H  2024-08-27T18:22:14.800Z
# 3                     4,H  2024-08-27T18:22:14.800Z
# 4                     4,H  2024-08-27T18:22:14.800Z
#
#                                        hash  \
# 0  93a59d4d8f26ec5507f34aeb06b86fe1e98f2f3d
# 1  74125142f6e1e0dc18bc4c90e832e6b3f32bff13
# 2  55ca100e2799d9613ce8dd9395ca5acc679de40c
# 3  e8fb0634984472c53d452fe862f458853a73ba43
# 4  bede4bd4b03e51fd25cb1d73d958d6b0d3877299
#
#                                      id   fips  year  outflow_returns  \
# 0  c2833057-166d-4f85-a53f-5e4ae70b1b5e  12001  2022         133864.0
# 1  6bc776fc-98e1-40f4-ab8d-c393a7cf0326  12003  2022          12078.0
# 2  5a5896ee-efca-45f4-85de-4cdc55c4f2c5  12007  2022          10888.0
# 3  202f3a2d-9bc2-47eb-917a-723b4cf7f588  12011  2022         999987.0
# 4  2cf3a8c1-765c-4309-9535-672f6de1d314  12013  2022           4986.0
#
#    outflow_people  outflow_agi  inflow_returns  inflow_people  inflow_agi  \
# 0        236905.0   10594863.0        131143.0       235518.0  10528909.0
# 1         25438.0     747938.0         12620.0        26869.0    806790.0
# 2         21990.0     601863.0         12262.0        24667.0    666370.0
# 3       1808085.0   93860199.0        994604.0      1786372.0  99337673.0
# 4         10408.0     261886.0          5402.0        11180.0    286455.0
#
#    net_migration_returns  net_migration_people matched_storm_id  \
# 0                -2721.0               -1387.0         AL172022
# 1                  542.0                1431.0         AL172022
# 2                 1374.0                2677.0         AL172022
# 3                -5383.0              -21713.0         AL172022
# 4                  416.0                 772.0         AL172022
#
#    max_wind_speed  min_pressure
# 0            65.0         980.0
# 1            65.0         980.0
# 2            65.0         980.0
# 3            65.0         980.0
# 4            65.0         980.0

# %%
hurricane_county_year = fema_migration_storms.groupby(['fips', 'year']).agg({
    'disasterNumber': 'count',
    'state': 'first',
    'designatedArea': 'first',
    'outflow_returns': 'first',
    'inflow_returns': 'first',
    'net_migration_returns': 'first',
    'outflow_people': 'first',
    'inflow_people': 'first',
    'net_migration_people': 'first',
    'outflow_agi': 'first',
    'inflow_agi': 'first',
    'max_wind_speed': 'max',
    'declarationTitle': lambda x: '; '.join(x.unique())
}).reset_index()

# Renaming for aesthetic reasons

hurricane_county_year.columns = [
    'fips', 'year', 'num_declarations', 'state', 'county_name',
    'outflow_returns', 'inflow_returns', 'net_migration_returns',
    'outflow_people', 'inflow_people', 'net_migration_people',
    'outflow_agi', 'inflow_agi', 'max_wind_speed', 'storms'
]

# %%
hurricane_county_year.isnull().sum()
# Out:
# fips                     0
# year                     0
# num_declarations         0
# state                    0
# county_name              0
# outflow_returns          2
# inflow_returns           2
# net_migration_returns    2
# outflow_people           2
# inflow_people            2
# net_migration_people     2
# outflow_agi              2
# inflow_agi               2
# max_wind_speed           0
# storms                   0
# dtype: int64

# %%
with pd.option_context('display.max_columns', None):
    display(hurricane_county_year.head())
# Out:
#     fips  year  num_declarations state                     county_name  \
# 0  12000  2017                 7    FL  Big Cypress Indian Reservation
# 1  12000  2019                 6    FL  Big Cypress Indian Reservation
# 2  12000  2022                21    FL  Big Cypress Indian Reservation
# 3  12001  2017                 2    FL                Alachua (County)
# 4  12001  2018                 1    FL                Alachua (County)
#
#    outflow_returns  inflow_returns  net_migration_returns  outflow_people  \
# 0        2074469.0       2347801.0               273332.0       3791041.0
# 1              NaN             NaN                    NaN             NaN
# 2              NaN             NaN                    NaN             NaN
# 3         129077.0        123305.0                -5772.0        240932.0
# 4         123477.0        119271.0                -4206.0        229029.0
#
#    inflow_people  net_migration_people  outflow_agi   inflow_agi  \
# 0      4366561.0              575520.0  114030354.0  160634007.0
# 1            NaN                   NaN          NaN          NaN
# 2            NaN                   NaN          NaN          NaN
# 3       233654.0               -7278.0    7964561.0    7645654.0
# 4       224269.0               -4760.0    7863874.0    7712832.0
#
#    max_wind_speed                                             storms
# 0           155.0  HURRICANE IRMA - SEMINOLE TRIBE OF FLORIDA; HU...
# 1           160.0                                  HURRICANE DORIAN
# 2           140.0  HURRICANE IAN - SEMINOLE TRIBE OF FLORIDA; HUR...
# 3           155.0                                     HURRICANE IRMA
# 4           140.0                                  HURRICANE MICHAEL

# %% [markdown]
# ## 6.3. Storm-level analysis

# %%
storm_impact = fema_migration_storms.groupby(['declarationTitle', 'year']).agg({
    'fips': 'nunique',
    'state': lambda x: ', '.join(x.unique()),
    'incidentBeginDate': 'first',
    'incidentEndDate': 'first',
    'outflow_returns': 'sum',
    'inflow_returns': 'sum',
    'net_migration_returns': 'sum',
    'outflow_people': 'sum',
    'inflow_people': 'sum',
    'net_migration_people': 'sum',
    'max_wind_speed': 'max'
}).reset_index()

storm_impact.columns = [
    'storm_name', 'year', 'counties_affected', 'states', 'start_date', 'end_date',
    'total_outflow_returns', 'total_inflow_returns', 'net_migration_returns',
    'total_outflow_people', 'total_inflow_people', 'net_migration_people',
    'max_wind_speed'
]

# %%
storm_impact.head()
# Out:
#                                   storm_name  year  counties_affected states  \
# 0                           HURRICANE DORIAN  2019                 14     FL
# 1                          HURRICANE DORIAN   2019                 68     FL
# 2                              HURRICANE ETA  2020                 13     FL
# 3                              HURRICANE IAN  2022                 68     FL
# 4  HURRICANE IAN - SEMINOLE TRIBE OF FLORIDA  2022                  1     FL
#
#                  start_date                  end_date  total_outflow_returns  \
# 0 2019-08-28 00:00:00+00:00 2019-09-09 00:00:00+00:00              3698332.0
# 1 2019-08-28 00:00:00+00:00 2019-09-09 00:00:00+00:00             10288218.0
# 2 2020-11-07 00:00:00+00:00 2020-11-12 00:00:00+00:00              2454637.0
# 3 2022-09-23 00:00:00+00:00 2022-11-04 00:00:00+00:00             11157556.0
# 4 2022-09-23 00:00:00+00:00 2022-11-04 00:00:00+00:00                    0.0
#
#    total_inflow_returns  net_migration_returns  total_outflow_people  \
# 0             3804258.0               105926.0             7124149.0
# 1            10557352.0               269134.0            19809584.0
# 2             2614847.0               160210.0             4711829.0
# 3            11679277.0               521721.0            20470591.0
# 4                   0.0                    0.0                   0.0
#
#    total_inflow_people  net_migration_people  max_wind_speed
# 0            7339404.0              215255.0           160.0
# 1           20358220.0              548636.0           160.0
# 2            5026366.0              314537.0           130.0
# 3           21500369.0             1029778.0           140.0
# 4                  0.0                   0.0           140.0

# %%
storm_impact = storm_impact.sort_values(['year', 'net_migration_people']).reset_index(drop=True)
storm_impact.head()
# Out:
#                                    storm_name  year  counties_affected states  \
# 0                              HURRICANE NATE  2017                  2     FL
# 1                              HURRICANE IRMA  2017                 68     FL
# 2  HURRICANE IRMA - SEMINOLE TRIBE OF FLORIDA  2017                  1     FL
# 3                           HURRICANE MICHAEL  2018                 35     FL
# 4                            HURRICANE DORIAN  2019                 14     FL
#
#                  start_date                  end_date  total_outflow_returns  \
# 0 2017-10-07 00:00:00+00:00 2017-10-11 00:00:00+00:00               244205.0
# 1 2017-09-04 00:00:00+00:00 2017-10-18 00:00:00+00:00             22355369.0
# 2 2017-09-04 00:00:00+00:00 2017-10-04 00:00:00+00:00             12446814.0
# 3 2018-10-07 00:00:00+00:00 2018-10-19 00:00:00+00:00              3178448.0
# 4 2019-08-28 00:00:00+00:00 2019-09-09 00:00:00+00:00              3698332.0
#
#    total_inflow_returns  net_migration_returns  total_outflow_people  \
# 0              255926.0                11721.0              496954.0
# 1            23395933.0              1040564.0            43232341.0
# 2            14086806.0              1639992.0            22746246.0
# 3             3283956.0               105508.0             6218154.0
# 4             3804258.0               105926.0             7124149.0
#
#    total_inflow_people  net_migration_people  max_wind_speed
# 0             522966.0               26012.0            80.0
# 1           45432841.0             2200500.0           155.0
# 2           26199366.0             3453120.0           155.0
# 3            6438886.0              220732.0           140.0
# 4            7339404.0              215255.0           160.0

# %% [markdown]
# ## 6.4. Trends over time

# %%
migration_trends = migration_summary.groupby('year').agg({
    'fips': 'count',
    'outflow_returns': 'sum',
    'inflow_returns': 'sum',
    'net_migration_returns': 'sum',
    'outflow_people': 'sum',
    'inflow_people': 'sum',
    'net_migration_people': 'sum'
}).reset_index()

migration_trends.columns = [
    'year', 'counties_with_data', 'total_outflow_returns', 'total_inflow_returns',
    'net_migration_returns', 'total_outflow_people', 'total_inflow_people', 'net_migration_people'
]

# %%
migration_trends.head()
# Out:
#    year  counties_with_data  total_outflow_returns  total_inflow_returns  \
# 0  2017                  68               12214919              12871867
# 1  2018                  68               11767323              12183814
# 2  2019                  67               10288218              10557352
# 3  2020                  67               10512010              10855127
# 4  2021                  67               10824102              11361031
#
#    net_migration_returns  total_outflow_people  total_inflow_people  \
# 0                 656948              23511691             24899701
# 1                 416491              22504353             23372328
# 2                 269134              19809584             20358220
# 3                 343117              20435194             21146454
# 4                 536929              20060013             21142945
#
#    net_migration_people
# 0               1388010
# 1                867975
# 2                548636
# 3                711260
# 4               1082932

# %% [markdown]
# # 7. Exporting

# %%
os.makedirs('data/merge', exist_ok=True)

# %%
fema_migration_storms.head()
# Out:
#   femaDeclarationString  disasterNumber state declarationType  \
# 0            DR-4680-FL            4680    FL              DR
# 1            DR-4680-FL            4680    FL              DR
# 2            DR-4680-FL            4680    FL              DR
# 3            DR-4680-FL            4680    FL              DR
# 4            DR-4680-FL            4680    FL              DR
#
#             declarationDate  fyDeclared incidentType  declarationTitle  \
# 0 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 1 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 2 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 3 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
# 4 2022-12-13 00:00:00+00:00        2023    Hurricane  HURRICANE NICOLE
#
#    ihProgramDeclared  iaProgramDeclared  ...  outflow_people  outflow_agi  \
# 0                  0                  0  ...        236905.0   10594863.0
# 1                  0                  0  ...         25438.0     747938.0
# 2                  0                  0  ...         21990.0     601863.0
# 3                  0                  0  ...       1808085.0   93860199.0
# 4                  0                  0  ...         10408.0     261886.0
#
#   inflow_returns inflow_people  inflow_agi  net_migration_returns  \
# 0       131143.0      235518.0  10528909.0                -2721.0
# 1        12620.0       26869.0    806790.0                  542.0
# 2        12262.0       24667.0    666370.0                 1374.0
# 3       994604.0     1786372.0  99337673.0                -5383.0
# 4         5402.0       11180.0    286455.0                  416.0
#
#    net_migration_people  matched_storm_id  max_wind_speed min_pressure
# 0               -1387.0          AL172022            65.0        980.0
# 1                1431.0          AL172022            65.0        980.0
# 2                2677.0          AL172022            65.0        980.0
# 3              -21713.0          AL172022            65.0        980.0
# 4                 772.0          AL172022            65.0        980.0
#
# [5 rows x 41 columns]

# %%
# 1. Merged dataset

output_file = os.path.join('data/merge', 'hurricane_migration_combined.csv')
fema_migration_storms.to_csv(output_file, index=False)

# %%
# 2. County summary

output_file = os.path.join('data/merge', 'hurricane_county_impacts.csv')
hurricane_county_summary.to_csv(output_file, index=False)

# %%
# 3. County-year summary

output_file = os.path.join('data/merge', 'hurricane_county_year_impacts.csv')
hurricane_county_year.to_csv(output_file, index=False)

# %%
# 4. Storm impact summary

output_file = os.path.join('data/merge', 'hurricane_storm_impacts.csv')
storm_impact.to_csv(output_file, index=False)
