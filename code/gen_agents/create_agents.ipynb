# %% [markdown]
# ## set up

# %%
import os
import re
import json
import glob
import fileinput
import textwrap

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### read in personas

# %%
persona_files = glob.glob('/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/*.json')
persona_files
# Out:
# ['/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_0_Duval_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_1_Duval_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_2_Duval_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_3_Duval_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_4_Duval_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_5_Broward_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_6_Broward_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_7_Broward_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_8_Broward_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_9_Broward_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_10_Alachua_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_11_Alachua_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_12_Alachua_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_13_Alachua_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_14_Alachua_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_20_Bay_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_21_Bay_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_22_Bay_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_23_Bay_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_24_Bay_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_25_Leon_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_26_Leon_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_27_Leon_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_28_Leon_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_29_Leon_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_30_Brevard_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_31_Brevard_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_32_Brevard_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_33_Brevard_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_34_Brevard_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_35_Pasco_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_36_Pasco_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_37_Pasco_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_38_Pasco_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_39_Pasco_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_40_Seminole_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_41_Seminole_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_42_Seminole_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_43_Seminole_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_44_Seminole_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_50_Osceola_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_51_Osceola_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_52_Osceola_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_53_Osceola_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_54_Osceola_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_55_Hillsborough_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_56_Hillsborough_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_57_Hillsborough_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_58_Hillsborough_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_59_Hillsborough_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_60_Pinellas_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_61_Pinellas_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_62_Pinellas_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_63_Pinellas_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_64_Pinellas_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_65_Manatee_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_66_Manatee_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_67_Manatee_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_68_Manatee_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_69_Manatee_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_70_Sarasota_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_71_Sarasota_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_72_Sarasota_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_73_Sarasota_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_74_Sarasota_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_75_Lee_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_76_Lee_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_77_Lee_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_78_Lee_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_79_Lee_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_15_StJohns_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_16_StJohns_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_17_StJohns_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_18_StJohns_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_19_StJohns_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_45_PalmBeach_base.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_46_PalmBeach_max.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_47_PalmBeach_min.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_48_PalmBeach_random.json',
#  '/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/persona/json/persona_row_49_PalmBeach_random.json']

# %%
personas_dict = {}

random_count_tracker = {}

for file_path in persona_files:
    with open(file_path, "r") as f:
        persona_data = json.load(f)

    county = persona_data.get('county')
    mode = persona_data.get('mode')

    if not county or not mode:
        print(f"Skipping file: Missing county/mode in JSON for {os.path.basename(file_path)}")
        continue

    key = None

    if mode == 'random':
        current_count = random_count_tracker.get(county, 0) + 1
        random_count_tracker[county] = current_count
        key = f"{county}_{mode}_{current_count}"

    else:
        key = f"{county}_{mode}"

    personas_dict[key] = persona_data

# %%
print(list(personas_dict.keys()))
# Out:
# ['Duval_base', 'Duval_max', 'Duval_min', 'Duval_random_1', 'Duval_random_2', 'Broward_base', 'Broward_max', 'Broward_min', 'Broward_random_1', 'Broward_random_2', 'Alachua_base', 'Alachua_max', 'Alachua_min', 'Alachua_random_1', 'Alachua_random_2', 'St. Johns_base', 'St. Johns_max', 'St. Johns_min', 'St. Johns_random_1', 'St. Johns_random_2', 'Bay_base', 'Bay_max', 'Bay_min', 'Bay_random_1', 'Bay_random_2', 'Leon_base', 'Leon_max', 'Leon_min', 'Leon_random_1', 'Leon_random_2', 'Brevard_base', 'Brevard_max', 'Brevard_min', 'Brevard_random_1', 'Brevard_random_2', 'Pasco_base', 'Pasco_max', 'Pasco_min', 'Pasco_random_1', 'Pasco_random_2', 'Seminole_base', 'Seminole_max', 'Seminole_min', 'Seminole_random_1', 'Seminole_random_2', 'Palm Beach_base', 'Palm Beach_max', 'Palm Beach_min', 'Palm Beach_random_1', 'Palm Beach_random_2', 'Osceola_base', 'Osceola_max', 'Osceola_min', 'Osceola_random_1', 'Osceola_random_2', 'Hillsborough_base', 'Hillsborough_max', 'Hillsborough_min', 'Hillsborough_random_1', 'Hillsborough_random_2', 'Pinellas_base', 'Pinellas_max', 'Pinellas_min', 'Pinellas_random_1', 'Pinellas_random_2', 'Manatee_base', 'Manatee_max', 'Manatee_min', 'Manatee_random_1', 'Manatee_random_2', 'Sarasota_base', 'Sarasota_max', 'Sarasota_min', 'Sarasota_random_1', 'Sarasota_random_2', 'Lee_base', 'Lee_max', 'Lee_min', 'Lee_random_1', 'Lee_random_2']

# %%
duval_keys = sorted([k for k in personas_dict.keys() if k.startswith('Duval')])
print(duval_keys)
# Out:
# ['Duval_base', 'Duval_max', 'Duval_min', 'Duval_random_1', 'Duval_random_2']

# %% [markdown]
# ### connect to repo

# %%
# !git clone https://github.com/StanfordHCI/genagents.git
# Out:
# Cloning into 'genagents'...
# remote: Enumerating objects: 17645, done.
# remote: Counting objects: 100% (4461/4461), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 17645 (delta 4449), reused 4447 (delta 4447), pack-reused 13184 (from 1)
# Receiving objects: 100% (17645/17645), 5.93 MiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (6992/6992), done.
# Updating files: 100% (14052/14052), done.

# %%
os.chdir("genagents")
os.getcwd()
# Out:
# '/content/genagents'

# %%
old_path = '/content/genagents/simulation_engine/example-settings.py'
new_path = '/content/genagents/simulation_engine/settings.py'

os.rename(old_path, new_path)

# %%
file_path = '/content/genagents/simulation_engine/settings.py'

my_api_key = # ENTER API KEY HERE
my_key_owner = # ENTER API KEY OWNER HERE

with fileinput.FileInput(file_path, inplace=True) as file:
    for line in file:
        if line.startswith('OPENAI_API_KEY ='):
            print(f'OPENAI_API_KEY = "{my_api_key}"')
        elif line.startswith('KEY_OWNER ='):
            print(f'KEY_OWNER = "{my_key_owner}"')
        else:
            print(line, end='')

# %% [markdown]
# ### import genagents

# %%
from genagents.genagents import GenerativeAgent

# %% [markdown]
# ### create agents with personas

# %%
agent_bank_path = "/content/drive/Shareddrives/AmFamSharedDrive/UW_Madison_DSHB_AmFam_Capstone/02_Data/agent_bank/"

for key, persona_data in personas_dict.items():

  agent = GenerativeAgent()
  agent.update_scratch(persona_data)

  filename = f"agent_{key}"
  agent.save(os.path.join(agent_bank_path, filename))

  print(f"Agent successfully saved: {filename}")
# Out:
# Agent successfully saved: agent_Duval_base
# Agent successfully saved: agent_Duval_max
# Agent successfully saved: agent_Duval_min
# Agent successfully saved: agent_Duval_random_1
# Agent successfully saved: agent_Duval_random_2
# Agent successfully saved: agent_Broward_base
# Agent successfully saved: agent_Broward_max
# Agent successfully saved: agent_Broward_min
# Agent successfully saved: agent_Broward_random_1
# Agent successfully saved: agent_Broward_random_2
# Agent successfully saved: agent_Alachua_base
# Agent successfully saved: agent_Alachua_max
# Agent successfully saved: agent_Alachua_min
# Agent successfully saved: agent_Alachua_random_1
# Agent successfully saved: agent_Alachua_random_2
# Agent successfully saved: agent_St. Johns_base
# Agent successfully saved: agent_St. Johns_max
# Agent successfully saved: agent_St. Johns_min
# Agent successfully saved: agent_St. Johns_random_1
# Agent successfully saved: agent_St. Johns_random_2
# Agent successfully saved: agent_Bay_base
# Agent successfully saved: agent_Bay_max
# Agent successfully saved: agent_Bay_min
# Agent successfully saved: agent_Bay_random_1
# Agent successfully saved: agent_Bay_random_2
# Agent successfully saved: agent_Leon_base
# Agent successfully saved: agent_Leon_max
# Agent successfully saved: agent_Leon_min
# Agent successfully saved: agent_Leon_random_1
# Agent successfully saved: agent_Leon_random_2
# Agent successfully saved: agent_Brevard_base
# Agent successfully saved: agent_Brevard_max
# Agent successfully saved: agent_Brevard_min
# Agent successfully saved: agent_Brevard_random_1
# Agent successfully saved: agent_Brevard_random_2
# Agent successfully saved: agent_Pasco_base
# Agent successfully saved: agent_Pasco_max
# Agent successfully saved: agent_Pasco_min
# Agent successfully saved: agent_Pasco_random_1
# Agent successfully saved: agent_Pasco_random_2
# Agent successfully saved: agent_Seminole_base
# Agent successfully saved: agent_Seminole_max
# Agent successfully saved: agent_Seminole_min
# Agent successfully saved: agent_Seminole_random_1
# Agent successfully saved: agent_Seminole_random_2
# Agent successfully saved: agent_Palm Beach_base
# Agent successfully saved: agent_Palm Beach_max
# Agent successfully saved: agent_Palm Beach_min
# Agent successfully saved: agent_Palm Beach_random_1
# Agent successfully saved: agent_Palm Beach_random_2
# Agent successfully saved: agent_Osceola_base
# Agent successfully saved: agent_Osceola_max
# Agent successfully saved: agent_Osceola_min
# Agent successfully saved: agent_Osceola_random_1
# Agent successfully saved: agent_Osceola_random_2
# Agent successfully saved: agent_Hillsborough_base
# Agent successfully saved: agent_Hillsborough_max
# Agent successfully saved: agent_Hillsborough_min
# Agent successfully saved: agent_Hillsborough_random_1
# Agent successfully saved: agent_Hillsborough_random_2
# Agent successfully saved: agent_Pinellas_base
# Agent successfully saved: agent_Pinellas_max
# Agent successfully saved: agent_Pinellas_min
# Agent successfully saved: agent_Pinellas_random_1
# Agent successfully saved: agent_Pinellas_random_2
# Agent successfully saved: agent_Manatee_base
# Agent successfully saved: agent_Manatee_max
# Agent successfully saved: agent_Manatee_min
# Agent successfully saved: agent_Manatee_random_1
# Agent successfully saved: agent_Manatee_random_2
# Agent successfully saved: agent_Sarasota_base
# Agent successfully saved: agent_Sarasota_max
# Agent successfully saved: agent_Sarasota_min
# Agent successfully saved: agent_Sarasota_random_1
# Agent successfully saved: agent_Sarasota_random_2
# Agent successfully saved: agent_Lee_base
# Agent successfully saved: agent_Lee_max
# Agent successfully saved: agent_Lee_min
# Agent successfully saved: agent_Lee_random_1
# Agent successfully saved: agent_Lee_random_2

# %% [markdown]
# *note:* fixed the names of St. Johns and Palm Beach agents in the drive directly
